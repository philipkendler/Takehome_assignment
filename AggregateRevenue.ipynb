# %%
import pandas as pd
pd.__version__
from pandas import DataFrame
import matplotlib.pyplot as plt
import numpy as np

# %%
data = pd.read_csv('summer_internship_takehome.csv')
data2 = data

# %%
monthly =  pd.DataFrame(columns=['Month', 'Aggregate Revenue'])
quarterly = pd.DataFrame(columns=['Quarter', 'Aggregate Revenue'])
monthly_costs = pd.DataFrame(columns=['Month', 'Aggregate Cost'])

# %%
january_revenue = 0
february_revenue = 0
march_revenue = 0
april_revenue = 0
may_revenue = 0
june_revenue = 0
july_revenue = 0
august_revenue = 0
september_revenue = 0
october_revenue = 0
november_revenue = 0
december_revenue = 0

for i in data.index:
    if data.at[i, 'Month'] == 1:
        january_revenue += data.at[i, 'Gross revenue']
    elif data.at[i, 'Month'] == 2:
        february_revenue += data.at[i, 'Gross revenue']
    elif data.at[i, 'Month'] == 3:
        march_revenue += data.at[i, 'Gross revenue']
    elif data.at[i, 'Month'] == 4:
        april_revenue += data.at[i, 'Gross revenue']
    elif data.at[i, 'Month'] == 5:
        may_revenue += data.at[i, 'Gross revenue']
    elif data.at[i, 'Month'] == 6:
        june_revenue += data.at[i, 'Gross revenue']
    elif data.at[i, 'Month'] == 7:
        july_revenue += data.at[i, 'Gross revenue']
    elif data.at[i, 'Month'] == 8:
        august_revenue += data.at[i, 'Gross revenue']
    elif data.at[i, 'Month'] == 9:
        september_revenue += data.at[i, 'Gross revenue']
    elif data.at[i, 'Month'] == 10:
        october_revenue += data.at[i, 'Gross revenue']
    elif data.at[i, 'Month'] == 11:
        november_revenue += data.at[i, 'Gross revenue']
    else:
        december_revenue += data.at[i, 'Gross revenue']
monthly = monthly.append({'Month': 'January', 'Aggregate Revenue': january_revenue}, ignore_index = True)
monthly = monthly.append({'Month': 'February', 'Aggregate Revenue': february_revenue}, ignore_index = True)
monthly = monthly.append({'Month': 'March', 'Aggregate Revenue': march_revenue}, ignore_index = True)
monthly = monthly.append({'Month': 'April', 'Aggregate Revenue': april_revenue}, ignore_index = True)
monthly = monthly.append({'Month': 'May', 'Aggregate Revenue': may_revenue}, ignore_index = True)
monthly = monthly.append({'Month': 'June', 'Aggregate Revenue': june_revenue}, ignore_index = True)
monthly = monthly.append({'Month': 'July', 'Aggregate Revenue': july_revenue}, ignore_index = True)
monthly = monthly.append({'Month': 'August', 'Aggregate Revenue': august_revenue}, ignore_index = True)
monthly = monthly.append({'Month': 'September', 'Aggregate Revenue': september_revenue}, ignore_index = True)
monthly = monthly.append({'Month': 'October', 'Aggregate Revenue': october_revenue}, ignore_index = True)
monthly = monthly.append({'Month': 'November', 'Aggregate Revenue': november_revenue}, ignore_index = True)
monthly = monthly.append({'Month': 'December', 'Aggregate Revenue': december_revenue}, ignore_index = True)
monthly.plot(x='Month', y='Aggregate Revenue', kind = 'bar')

# %%
first_quarter_revenue = 0
second_quarter_revenue = 0
third_quarter_revenue = 0
fourth_quarter_revenue = 0
for i in monthly.index:
    if monthly.at[i, 'Month'] == 'January' or monthly.at[i, 'Month'] == 'February' or monthly.at[i, 'Month'] == 'March':
        first_quarter_revenue += monthly.at[i, 'Aggregate Revenue']
    elif monthly.at[i, 'Month'] == 'April' or monthly.at[i, 'Month'] == 'May' or monthly.at[i, 'Month'] == 'June':
        second_quarter_revenue += monthly.at[i, 'Aggregate Revenue']
    elif monthly.at[i, 'Month'] == 'July' or monthly.at[i, 'Month'] == 'August' or monthly.at[i, 'Month'] == 'September':
        third_quarter_revenue += monthly.at[i, 'Aggregate Revenue']
    else:
        fourth_quarter_revenue += monthly.at[i, 'Aggregate Revenue']
quarterly = quarterly.append({'Quarter': '1st Quarter', 'Aggregate Revenue': first_quarter_revenue}, ignore_index = True)
quarterly = quarterly.append({'Quarter': '2nd Quarter', 'Aggregate Revenue': second_quarter_revenue}, ignore_index = True)
quarterly = quarterly.append({'Quarter': '3rd Quarter', 'Aggregate Revenue': third_quarter_revenue}, ignore_index = True)
quarterly = quarterly.append({'Quarter': '4th Quarter', 'Aggregate Revenue': fourth_quarter_revenue}, ignore_index = True)
quarterly.plot(x='Quarter', y='Aggregate Revenue', kind = 'bar')

# %%
january_costs = 0
february_costs = 0
march_costs = 0
april_costs = 0
may_costs = 0
june_costs = 0
july_costs = 0
august_costs = 0
september_costs = 0
october_costs = 0
november_costs = 0
december_costs = 0

for i in data.index:
    if data.at[i, 'Month'] == 1:
        january_costs += data.at[i, 'Fixed cost'] + data.at[i, 'Variable cost'] + data.at[i, 'Rental cost']
    elif data.at[i, 'Month'] == 2:
        february_costs += data.at[i, 'Fixed cost'] + data.at[i, 'Variable cost'] + data.at[i, 'Rental cost']
    elif data.at[i, 'Month'] == 3:
        march_costs += data.at[i, 'Fixed cost'] + data.at[i, 'Variable cost'] + data.at[i, 'Rental cost']
    elif data.at[i, 'Month'] == 4:
        april_costs += data.at[i, 'Fixed cost'] + data.at[i, 'Variable cost'] + data.at[i, 'Rental cost']
    elif data.at[i, 'Month'] == 5:
        may_costs += data.at[i, 'Fixed cost'] + data.at[i, 'Variable cost'] + data.at[i, 'Rental cost']
    elif data.at[i, 'Month'] == 6:
        june_costs += data.at[i, 'Fixed cost'] + data.at[i, 'Variable cost'] + data.at[i, 'Rental cost']
    elif data.at[i, 'Month'] == 7:
        july_costs += data.at[i, 'Fixed cost'] + data.at[i, 'Variable cost'] + data.at[i, 'Rental cost']
    elif data.at[i, 'Month'] == 8:
        august_costs += data.at[i, 'Fixed cost'] + data.at[i, 'Variable cost'] + data.at[i, 'Rental cost']
    elif data.at[i, 'Month'] == 9:
        september_costs += data.at[i, 'Fixed cost'] + data.at[i, 'Variable cost'] + data.at[i, 'Rental cost']
    elif data.at[i, 'Month'] == 10:
        october_costs += data.at[i, 'Fixed cost'] + data.at[i, 'Variable cost'] + data.at[i, 'Rental cost']
    elif data.at[i, 'Month'] == 11:
        november_costs += data.at[i, 'Fixed cost'] + data.at[i, 'Variable cost'] + data.at[i, 'Rental cost']
    else:
        december_costs += data.at[i, 'Fixed cost'] + data.at[i, 'Variable cost'] + data.at[i, 'Rental cost']
monthly_costs = monthly_costs.append({'Month': 'January', 'Aggregate Cost': january_costs}, ignore_index = True)
monthly_costs = monthly_costs.append({'Month': 'February', 'Aggregate Cost': february_costs}, ignore_index = True)
monthly_costs = monthly_costs.append({'Month': 'March', 'Aggregate Cost': march_costs}, ignore_index = True)
monthly_costs = monthly_costs.append({'Month': 'April', 'Aggregate Cost': april_costs}, ignore_index = True)
monthly_costs = monthly_costs.append({'Month': 'May', 'Aggregate Cost': may_costs}, ignore_index = True)
monthly_costs = monthly_costs.append({'Month': 'June', 'Aggregate Cost': june_costs}, ignore_index = True)
monthly_costs = monthly_costs.append({'Month': 'July', 'Aggregate Cost': july_costs}, ignore_index = True)
monthly_costs = monthly_costs.append({'Month': 'August', 'Aggregate Cost': august_costs}, ignore_index = True)
monthly_costs = monthly_costs.append({'Month': 'September', 'Aggregate Cost': september_costs}, ignore_index = True)
monthly_costs = monthly_costs.append({'Month': 'October', 'Aggregate Cost': october_costs}, ignore_index = True)
monthly_costs = monthly_costs.append({'Month': 'November', 'Aggregate Cost': november_costs}, ignore_index = True)
monthly_costs = monthly_costs.append({'Month': 'December', 'Aggregate Cost': december_costs}, ignore_index = True)
monthly_costs.plot(x='Month', y='Aggregate Cost', kind = 'bar')
